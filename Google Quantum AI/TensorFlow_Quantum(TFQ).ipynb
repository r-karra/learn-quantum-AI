# %% [markdown]
# <a href="https://colab.research.google.com/github/r-karra/learn-quantum-computing/blob/main/TensorFlow_Quantum(TFQ).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Setup
# Install TensorFlow and TensorFlow Quantum

# %%
# !uv pip install tensorflow==2.18.1 tensorflow-quantum==0.7.6
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 72 packages in 362ms
# Prepared 12 packages in 26.38s
# Uninstalled 6 packages in 1.51s
# Installed 12 packages in 605ms
#  + cirq-core==1.5.0
#  + cirq-google==1.5.0
#  - contourpy==1.3.3
#  + contourpy==1.3.2
#  + duet==0.2.9
#  - jax==0.7.2
#  + jax==0.5.3
#  - jaxlib==0.7.2
#  + jaxlib==0.5.3
#  + sortedcontainers==2.4.0
#  - tensorboard==2.19.0
#  + tensorboard==2.18.0
#  - tensorflow==2.19.0
#  + tensorflow==2.18.1
#  + tensorflow-quantum==0.7.6
#  - tf-keras==2.19.0
#  + tf-keras==2.18.0
#  + typedunits==0.0.2

# %% [markdown]
# Configure the use of Keras 2:

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"

# %%
from ast import increment_lineno
import tensorflow as tf
import tensorflow_quantum as tfq

import cirq
import sympy
import numpy as np

# Visualization tools
# %matplotlib inline
import matplotlib.pyplot as plt
from cirq.contrib.svg import SVGCircuit
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow_quantum/core/ops/math_ops/fidelity_op.py:30: SyntaxWarning: invalid escape sequence '\l'
#   |\langle \psi_{\text{programs[i]}}(\text{symbol_values[i]}) \mid
# /usr/local/lib/python3.12/dist-packages/tensorflow_quantum/core/ops/math_ops/inner_product_op.py:30: SyntaxWarning: invalid escape sequence '\l'
#   Calculates out[i][j][k] = $ \frac{\langle \psi_{\text{programs[i]}} \\
# /usr/local/lib/python3.12/dist-packages/tensorflow_quantum/core/ops/math_ops/inner_product_op.py:80: SyntaxWarning: invalid escape sequence '\l'
#   \langle \psi_{\text{programs[i]}}(\text{symbol_values[i]}) \mid
# /usr/local/lib/python3.12/dist-packages/tensorflow_quantum/datasets/spin_system.py:98: SyntaxWarning: invalid escape sequence '\s'
#   H = - \sum_{i} \sigma_i^z \sigma_{i+1}^z - g\sigma_i^x
# /usr/local/lib/python3.12/dist-packages/tensorflow_quantum/datasets/spin_system.py:329: SyntaxWarning: invalid escape sequence '\s'
# ...

# %%
a, b = sympy.symbols('a b')

# %%
# Create two qubits
q0, q1 = cirq.GridQubit.rect(1, 2)

circuit = cirq.Circuit(cirq.rx(a).on(q0), cirq.ry(b).on(q1), cirq.CNOT(q0, q1))

SVGCircuit(circuit)
